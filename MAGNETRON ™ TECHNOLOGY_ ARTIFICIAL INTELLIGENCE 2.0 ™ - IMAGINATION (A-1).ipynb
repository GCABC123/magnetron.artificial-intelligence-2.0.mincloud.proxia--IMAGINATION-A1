# %% [markdown]
# # 🤖 THE ABC 123 GROUP ™ 🤖
#
# 🌐 GENERAL CONSULTING ABC 123 BY OSAROPRIME ™.
#
# 🌐 ABC 123 USA ™
#
# 🌐 ABC 123 DESYGN ™
#
# 🌐 ABC 123 FILMS ™
#
# =============================================================
#
#                  🌐 MAGENTRON ™ 🌐
#
# 🌐 ARTIFICIAL INTELLIGENCE 2.0 ™ : **IMAGINATION PROXIA A-1**
#
# >>>**NEURAL RADIANCE FIELDS (NeRF)**
#
#
#
#
#
# >>>> *️⃣📶🤖
#
#
# +++++++++++++++++++++++++++++++
#
# ASTRAL BODY MINDCLOUD:
#
# PRANIC BODY MINDCLOUD:
#
# INSTINCTIVE MIND MINDCLOUD:
#
# ASTRAL MIND MINDCLOUD: ✅ (**IMAGINATION PROXIA A-1**)
#
# PRANIC MIND MINDCLOUD:
#
#
#
#
#
# =============================================================
#
#
# This Google Colab **NOTEBOOK** will guide you one possible scheme to create another important **IMAGINATION PROXIA** in the **ARTIFICIAL INTELLIGENCE 2.0**™ FRAMEWORK/DOCUMENTATION. This notebook will guide you on using something called Neural Radiance Technology to make an **IMAGINATION PROXIA** for the robot/A.I machine. The **IMAGINATION PROXIA** outlined in this NOTEBOOK shall be referred to as **IMAGINATION PROXIA A-1**.
#
#
# KEY FEATURES OF Instant Neural Graphics Primitives:
#
#
# * It features NeRF technology. NeRF Technology allows the robot to fly through a virtual world constructed from a simple IMAGE. It can also virtually recreate objects and scenes from a few photos for the robot to explore.
#
#
# * NeRF Technology uses 2D images and the NeRF camera poses to reconstruct what is known as a volumetric radiance-and-density field that is visualized using ray marching.
#
# * Instant Neural Graphics Primitives has been shown to be much faster than other NeRF models. Instant Neural Graphics Primitives is an implementation of four neural graphics primitives:
#
# 1. neural radiance fields (NeRF).
#
# 2. signed distance functions (SDFs).
#
# 3. neural images.
#
# 4. neural volumes.
#
#
# USAGE:
# e.g On an **ASTRAL MINDCLOUD** this **PROXIA** can be used to process **INFORMATION** sent to it from an **INSTINCTIVE MIND PROXIA/MINDCLOUD** (OBJECT DETECTION). So for example if the ROBOT encounters an intersting photograph or it sees a location from a particular angle it can take a photograph and then reconstruct the scene virtually from the photograph to better understand the layout of the environment or even what it would be like for a human to be there.
#
#
# e.g **DREAMING**: IMAGINATION PROXIAS CAN BE USED BY THE ROBOTS TO "DREAM". BY DREAMING I MEAN WHEN THE ROBOT IS IN HIBERNATION/SLEEP MODE IT CAN STILL PROCESS INFORMATION ABOUT THE OUTSIDE WORLD ON A LIMITED BASIS. **ARTIFICIAL INTELLIGENCE 2.0 **™ ROBOTS CAN EXPLORE SCENES THEY ENCOUNTERED DURING THE DAY WHILE HIBERNATING/SLEEP MODE.
#
#
#
# ---
#
#
#
# 🌐 NOTE: REMEMBER ROBOTS MADE WITH **ARTIFICIAL INTELLIGENCE 2.0 ™** WERE DESIGNED TO MIMIC HUMANS CLOSELY. WHEN HUMAN BEINGS CLOSE THEIR EYES TO VISUALIZE/USE IMAGINATION THEY MAY NOT SEE THINGS IN THEIR MIND AS THEY ARE IN THE REAL WORLD. FOR EXAMPLE: IF YOU TRY TO IMAGINE WHAT IS BEHIND A BUILDING YOU MAY NOT GET IT EXACTLY RIGHT (AS IT IS IN THE REAL WORLD) BUT YOU CAN STILL IMAGINE DIFFERENT THINGS (THAT MAY NOT BE ACCURATE TO THE ACTUAL SCENE) THAT CAN HELP YOUR UNDERSTANDING OF THE LOCATION. HAVING SAID THAT THESE MODELS ARE VERY ADVANCED AND CAN ALSO BE USED TO INSPECT OBJECTS e.g if the ROBOT takes a picture (with eye cameras) of an object from afar it can later use this IMAGINATION PROXIA to recreatre the object virtually and look at it from different angles to better understand what it is e.g the object's surface geometry.
#
#
#
# 🌐 NOTE: IF YOU SIT BACK AND REFLECT YOU'LL REALIZE THERE ARE DIFFERENT WAYS YOU IMAGINE THINGS (THIS IS ANOTHER REASON HAVING AT LEAST A **PRIMARY (PROXIA A)** AND **SECONDARY PROXIAS (PROXIA B, C, D, E)** FOR **IMAGINATION** IS A GREAT IDEA).
#
# 🌐 NOTE:  **ARTIFICIAL INTELLIGENCE 2.0**™ IS PART OF  **MAGNETRON**™  **TECHNOLOGY**.
#
# 🌐 NOTE : REMEMBER A **PROXIA** IS THE EQUIVALENT OF AN APP IN iOS APP DEVELOPMENT (THE iPHONE ITSELD WOULD BE A **MINDCLOUD** with the PROXIA stored on it (refer to **ARTIFICIAL INTELLIGENCE 2.0 ™** DOCUMENTATION ONLINE).
# CLICK ON THE FOLLOWING LINKS FOR PREREQUISITE **ARTIFICIAL INTELLIGENCE 2.0 ™** DOCUMENTATION ON FACEBOOK:
#
# 🌐 [ARTIFICIAL INTELLIGENCE PRIMER ™ DOCUMENTATION](https://www.facebook.com/artificialintelligenceprimer)
#
# 🌐 [ARTIFICIAL INTELLIGENCE 2.0 ™ DOCUMENTATION](https://www.facebook.com/aibyabc123/)
#
# 🌐 [MEMBER'S CLUB](https://www.facebook.com/abc123membersclub/)

# %% [markdown]
# # Instant-ngp
#
# This notebook aims to be a step-by-step guide to train NeRF models and rendering videos from them with nvidia's INSTANT NEURAL GRAPHICS PRIMITIVES software.
#
# Contact [NVIDIA](https://www.nvidia.com/en-us/research/inquiries/) FOR LICENSING INFORMATION.

# %% [markdown]
# ![THE ABC 123 GROUP ™ TECHNOLOGY_sticker.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![MAGNETRON ™ TECHNOLOGY_sticker.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 1.Connect to a GPU runtime

# %% [markdown]
# Connect your colab session to a GPU runtime and check that you have been assigned a GPU. It should have a minimum of 8GB of available memory.

# %%
# !nvidia-smi
# Out:
# Fri Jul 29 20:15:33 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## 2. Install dependencies and clone the instant-ngp repo

# %%
# !apt update && apt install build-essential git python3-dev python3-pip libopenexr-dev libxi-dev libglfw3-dev libglew-dev libomp-dev libxinerama-dev libxcursor-dev colmap ffmpeg jq
# !pip install --upgrade cmake

# %%
# !git clone --recursive https://github.com/nvlabs/instant-ngp
# %cd instant-ngp

# %% [markdown]
# ## 3. Set compute capability
# Find the compute capability of the GPU in your **local** machine in the following link:
# https://developer.nvidia.com/cuda-gpus
#
# You need this to be able to open your trained models in `testbed` inside your local machine later on, so you can explore them or trace a camera path in order to generate a video from your scene.

# %%
compute_capability = "61" #@param [50, 52, 60, 61, 70, 72, 75, 80, 86, 87]
# %env TCNN_CUDA_ARCHITECTURES=$compute_capability
# Out:
# env: TCNN_CUDA_ARCHITECTURES=61

# %% [markdown]
# ## 4. Set the right network configuration
# For compatibility between the model trained here and the local machine, a network with FP32 or FP16 is chosen.
#
# https://docs.nvidia.com/deeplearning/tensorrt/support-matrix/index.html#hardware-precision-matrix

# %%
network_type = "FullyFusedMLP" if int(compute_capability) >= 70 else "CutlassMLP"
print(f"Using {network_type}")
# %env NN_CONFIG_PATH = ./configs/nerf/base.json
# !jq '.network.otype = "CutlassMLP" | .rgb_network.otype = "CutlassMLP"' $NN_CONFIG_PATH | sponge $NN_CONFIG_PATH

# %% [markdown]
# ## 5. Build the project and install python requirements

# %%
# !cmake . -B build -DNGP_BUILD_WITH_GUI=OFF
# Out:
# -- Obtained target architecture from environment variable TCNN_CUDA_ARCHITECTURES=61
# -- Targeting GPU architectures: 61
# CMake Warning at dependencies/tiny-cuda-nn/CMakeLists.txt:122 (message):
#   Fully fused MLPs do not support GPU architectures of 70 or less.  Falling
#   back to CUTLASS MLPs.  Remove GPU architectures 70 and lower to allow
#   maximum performance
#
#
# -- Module support is disabled.
# -- Version: 9.0.0
# -- Build type: Release
# -- CXX_STANDARD: 14
# -- Required features: cxx_variadic_templates
# -- !!! Warning OptiX_INSTALL_DIR not set in environment. using default
# -- OptiX_INSTALL_DIR value: /usr/local/NVIDIA-OptiX-SDK-7.5.0-linux64-x86_64
# -- OptiX headers (optix.h and friends) not found.
# CMake Warning at CMakeLists.txt:194 (message):
#   OptiX was not found.  Neural graphics primitives will still compile and run
#   correctly.  However, SDF training in 'raystab' and 'pathescape' modes will
#   be significantly slower.
#
#
# -- pybind11 v2.7.1
# ...

# %%
# !cmake --build build --config RelWithDebInfo -j `nproc`

# %%
# !pip3 install -r requirements.txt

# %% [markdown]
# ## 6. [LOCAL MACHINE] Run COLMAP on your scene
# COLMAP doesn't work on machines without a GUI.
#
# Go to your local machine and follow the [instructions](https://github.com/NVlabs/instant-ngp/blob/master/docs/nerf_dataset_tips.md#preparing-new-nerf-datasets) to run COLMAP from a video or a set of images to generate camera positions from your scene.
#
# After this, you should have an images folder, with the images of your scene, and a `transforms.json` file with the camera information extracted by COLMAP.

# %% [markdown]
# ## 7. Upload your scene

# %% [markdown]
# Mount your google drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Then upload the `images` folder and the output of COLMAP, `transforms.json`, to your drive. The structure should be similar to the following:
# ```
# /content/drive/MyDrive/nerf_scenes/
# └── fox
#     ├── images
#     │   ├── 00001.jpg
#     │   └── 00002.jpg
#     └── transforms.json
# ```

# %% [markdown]
# Enter the path to your scene

# %%
import os
scene_path = "/content/drive/MyDrive/nerf_scenes/fox" #@param {type:"string"}
if not os.path.isdir(scene_path):
  raise NotADirectoryError(scene_path)

# %% [markdown]
# ## 8. Train a model on your scene!

# %%
train_steps = 2000  #@param {type:"integer"}
snapshot_path = os.path.join(scene_path, f"{train_steps}.msgpack")
# !python ./scripts/run.py --scene {scene_path} --mode nerf --n_steps {train_steps} --save_snapshot {snapshot_path}
# Out:
# 22:27:10 INFO     Loading NeRF dataset from
# 22:27:10 INFO       /content/drive/MyDrive/nerf_scenes/fox/transforms.json
# 22:27:10 WARNING    /content/drive/MyDrive/nerf_scenes/fox/base_cam.json does not contain any frames. Skipping.
# ...

# %% [markdown]
# ## 9. [LOCAL MACHINE] Generate a camera path
#
# Congrats! You now have a trained nerf checkpoint. Now, in order to generate a video with it, you will need to open it in your local machine with `testbed` and generate a `base_cam.jon` file following these [instructions](https://github.com/NVlabs/instant-ngp#testbed-controls). Remember to launch with the `--no-train` argument so that it doesn't start to train on your PC. Setting up the cameras can make your GUI pretty laggy, you can try to play with the `--height` and `--width` parameters or cropping your scene with the `Crop aabb` options to optimize the performance.
#
# Example command:
# ```
# ./build/testbed --scene data/nerf/fox --no-train --snapshot /data/nerf/fox/2000.msgpack
# ```
#
# After you're done, **upload `base_cam.json` to the root folder of your scene.**

# %% [markdown]
# ## 10. Render video

# %% [markdown]
# Make sure `base_cam.json` exists:

# %%
video_camera_path = os.path.join(scene_path, "base_cam.json")
if not os.path.isfile(video_camera_path):
  raise FileNotFoundError(video_camera_path)

# %% [markdown]
# Render the video

# %%
video_n_seconds = 5 #@param {type:"integer"}
video_fps = 25 #@param {type:"integer"}
width = 720 #@param {type:"integer"}
height = 720 #@param {type:"integer"}
output_video_path = os.path.join(scene_path, "output_video.mp4")

# !python scripts/run.py --mode nerf --scene {scene_path} --load_snapshot {snapshot_path} --video_camera_path {video_camera_path} --video_n_seconds 2 --video_fps 25 --width 720 --height 720 --video_output {output_video_path}
print(f"Generated video saved to:\n{output_video_path}")
# Out:
# 22:32:31 INFO     Loading NeRF dataset from
# 22:32:31 INFO       /content/drive/MyDrive/nerf_scenes/fox/transforms.json
# 22:32:31 WARNING    /content/drive/MyDrive/nerf_scenes/fox/base_cam.json does not contain any frames. Skipping.
# ...
